# %% [markdown]
# <a href="https://colab.research.google.com/github/Ebrahim-Zamani/Project/blob/main/Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import tree                             # sklearn tree model for decision trees
from sklearn.model_selection import train_test_split # for partitioning data
from sklearn.model_selection import cross_val_score  # for cross validation
from sklearn.metrics import roc_auc_score            # to asses decision tree perforamce

# to upload local files
import io
from google.colab import files             

import numpy as np                                   # array, vector, matrix calculations
import pandas as pd                                  # dataFrame handling

from matplotlib import pyplot as plt                 # plotting
import seaborn as sns                                # slightly better plotting  

SEED = 12345

# %%
from google.colab import files
  
  
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2e8611e6-d4e0-4e31-bae3-8f3ac3c178e4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2e8611e6-d4e0-4e31-bae3-8f3ac3c178e4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving credit_line_increase.csv to credit_line_increase (4).csv

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['credit_line_increase.csv']))

# %%
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  RACE  ...  PAY_AMT4  PAY_AMT5  PAY_AMT6  DELINQ_NEXT
# 0   1      20000    2   1.0  ...         0         0         0            1
# 1   2     120000    2   2.0  ...      1000         0      2000            1
# 2   3      90000    2   3.0  ...      1000      1000      5000            0
# 3   4      50000    2   4.0  ...      1100      1069      1000            0
# 4   5      50000    1   3.0  ...      9000       689       679            0
#
# [5 rows x 26 columns]

# %%
print("Name of the columns: ")
for cl in df.columns:
        print(cl)
# Out:
# Name of the columns:
# ID
# LIMIT_BAL
# SEX
# RACE
# EDUCATION
# MARRIAGE
# AGE
# PAY_0
# PAY_2
# PAY_3
# PAY_4
# PAY_5
# PAY_6
# BILL_AMT1
# BILL_AMT2
# BILL_AMT3
# BILL_AMT4
# BILL_AMT5
# BILL_AMT6
# PAY_AMT1
# PAY_AMT2
# PAY_AMT3
# PAY_AMT4
# PAY_AMT5
# PAY_AMT6
# DELINQ_NEXT

# %%
df.isnull().any().sum()
# Out:
# 0

# %%
missing = df.isnull().sum()

print(missing)
# Out:
# ID             0
# LIMIT_BAL      0
# SEX            0
# RACE           0
# EDUCATION      0
# MARRIAGE       0
# AGE            0
# PAY_0          0
# PAY_2          0
# PAY_3          0
# PAY_4          0
# PAY_5          0
# PAY_6          0
# BILL_AMT1      0
# BILL_AMT2      0
# BILL_AMT3      0
# BILL_AMT4      0
# BILL_AMT5      0
# BILL_AMT6      0
# PAY_AMT1       0
# PAY_AMT2       0
# PAY_AMT3       0
# PAY_AMT4       0
# PAY_AMT5       0
# PAY_AMT6       0
# DELINQ_NEXT    0
# dtype: int64

# %%
df.describe()
# Out:
#                  ID       LIMIT_BAL  ...       PAY_AMT6   DELINQ_NEXT
# count  30000.000000    30000.000000  ...   30000.000000  30000.000000
# mean   15000.500000   167484.322667  ...    5215.502567      0.221200
# std     8660.398374   129747.661567  ...   17777.465775      0.415062
# min        1.000000    10000.000000  ...       0.000000      0.000000
# 25%     7500.750000    50000.000000  ...     117.750000      0.000000
# 50%    15000.500000   140000.000000  ...    1500.000000      0.000000
# 75%    22500.250000   240000.000000  ...    4000.000000      0.000000
# max    30000.000000  1000000.000000  ...  528666.000000      1.000000
#
# [8 rows x 26 columns]

# %%
df.corr()
# Out:
#                    ID  LIMIT_BAL       SEX  ...  PAY_AMT5  PAY_AMT6  DELINQ_NEXT
# ID           1.000000   0.026179  0.018497  ...  0.000652  0.003000    -0.013952
# LIMIT_BAL    0.026179   1.000000  0.024755  ...  0.217202  0.219595    -0.153520
# SEX          0.018497   0.024755  1.000000  ... -0.001667 -0.002766    -0.039961
# RACE        -0.000710   0.044173  0.006149  ...  0.022148  0.020259    -0.303811
# EDUCATION    0.039177  -0.219161  0.014232  ... -0.040358 -0.037200     0.028006
# MARRIAGE    -0.029079  -0.108139 -0.031389  ... -0.001205 -0.006641    -0.024339
# AGE          0.018678   0.144713 -0.090874  ...  0.022850  0.019478     0.013890
# PAY_0       -0.030575  -0.271214 -0.057643  ... -0.058190 -0.058673     0.324794
# PAY_2       -0.011215  -0.296382 -0.070771  ... -0.037093 -0.036500     0.263551
# PAY_3       -0.018494  -0.286123 -0.066096  ... -0.035863 -0.035861     0.235253
# PAY_4       -0.002735  -0.267460 -0.060173  ... -0.033590 -0.026565     0.216614
# ...

# %%
df.hist(figsize=(20, 15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7faa75526b10>,
# ...
#       dtype=object)

# %%
from sklearn.model_selection import train_test_split

# %%
df.head(2)
# Out:
#         ID  LIMIT_BAL  SEX  RACE  ...  PAY_AMT4  PAY_AMT5  PAY_AMT6  DELINQ_NEXT
# 3419  3420     360000    1   1.0  ...      2223      2091      9890            0
# 2209  2210      50000    2   4.0  ...      1100      1000      1000            0
#
# [2 rows x 26 columns]

# %%
X1 = df.iloc[: , 7:24]
X2 = df['LIMIT_BAL']
X = pd.concat([X2,X1],axis=1)
y = df['DELINQ_NEXT']

# %%
X.columns
# Out:
# Index(['LIMIT_BAL', 'PAY_0', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6',
#        'BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5',
#        'BILL_AMT6', 'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4',
#        'PAY_AMT5'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test_valid, y_train, y_test_valid = train_test_split(X, y, test_size=0.5, random_state=SEED)

# %%
X_valid,X_test,y_valid,y_test=train_test_split(X_test_valid,y_test_valid,test_size=0.5, random_state=SEED)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
max_depth=12
candidate_models={}
for i in range(0,max_depth):
  clf=DecisionTreeClassifier(max_depth=i+1)
  clf.fit(X_train,y_train)

  train_phat=clf.predict_proba(X_train)[:,1]
  valid_phat=clf.predict_proba(X_valid)[:,1]

  train_auc=roc_auc_score(y_train,train_phat)
  valid_auc=roc_auc_score(y_valid,valid_phat)


  cv_scores=cross_val_score(clf,X_valid,y_valid,scoring="roc_auc",cv=5)
  cv_std=np.std(cv_scores)

candidate_models[i+1]={}
candidate_models[i+1]["Model"]=clf
candidate_models[i+1]["Training AUC"]=train_auc
candidate_models[i+1]["Validation AUC"]=valid_auc
candidate_models[i+1]["5-fold SD"]=cv_std

# %%
candidate_results=pd.DataFrame.from_dict(candidate_models,orient="index")
fig, ax=plt.subplots(figsize=(8,8))
_=candidate_results[["Training AUC","Validation AUC"]].plot(title="Iteration plot",
                                                            ax=ax)
_=ax.set_xlabel("Tree Depth")
_=ax.set_ylabel("AUC")

# %%
candidate_results.iloc[:,1:]
# Out:
#     Training AUC  Validation AUC  5-fold SD
# 12      0.871427        0.692373    0.00978

# %%
best_model=candidate_models[6]['Model']
fig=plt.figure(figsize=(400,70))
_=tree.plot_tree
